# %%
import requests as req

# %%
url = "https://api.github.com/events"
headers = {"Accept" : "application/json"}
r = req.get(url,headers)

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'id': '10197283089',
#   'type': 'PushEvent',
#   'actor': {'id': 9354925,
#    'login': 'nexus166',
#    'display_login': 'nexus166',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nexus166',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9354925?'},
#   'repo': {'id': 201968298,
#    'name': 'nexus166/barium',
#    'url': 'https://api.github.com/repos/nexus166/barium'},
#   'payload': {'push_id': 3916622116,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '26676c32d6dce76f39e43e34a91feb2aeab81908',
#    'before': '8fe4e85e87b3b15378a74b14fbc5b5561aac7d6c',
#    'commits': [{'sha': '26676c32d6dce76f39e43e34a91feb2aeab81908',
#      'author': {'email': 'szampardi@deepnull.com', 'name': 'nexus166'},
#      'message': 'init',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nexus166/barium/commits/26676c32d6dce76f39e43e34a91feb2aeab81908'}]},
#   'public': True,
#   'created_at': '2019-08-12T23:39:18Z'},
#  {'id': '10197283088',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 139127419,
#    'name': 'niranjan94/cloudwatch-exporter',
#    'url': 'https://api.github.com/repos/niranjan94/cloudwatch-exporter'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/aws-sdk-2.508.0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-08-12T23:39:18Z'},
#  {'id': '10197283085',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 4864182,
#    'login': 'flovo',
#    'display_login': 'flovo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/flovo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4864182?'},
#   'repo': {'id': 83054351,
#    'name': 'online-go/online-go.com',
#    'url': 'https://api.github.com/repos/online-go/online-go.com'},
#   'payload': {'action': 'opened',
#    'number': 861,
#    'pull_request': {'url': 'https://api.github.com/repos/online-go/online-go.com/pulls/861',
#     'id': 306696914,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzA2Njk2OTE0',
#     'html_url': 'https://github.com/online-go/online-go.com/pull/861',
#     'diff_url': 'https://github.com/online-go/online-go.com/pull/861.diff',
#     'patch_url': 'https://github.com/online-go/online-go.com/pull/861.patch',
#     'issue_url': 'https://api.github.com/repos/online-go/online-go.com/issues/861',
#     'number': 861,
#     'state': 'open',
#     'locked': False,
#     'title': 'limit the number of AI suggestions to leelas top 6',
#     'user': {'login': 'flovo',
#      'id': 4864182,
#      'node_id': 'MDQ6VXNlcjQ4NjQxODI=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/4864182?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/flovo',
#      'html_url': 'https://github.com/flovo',
#      'followers_url': 'https://api.github.com/users/flovo/followers',
#      'following_url': 'https://api.github.com/users/flovo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/flovo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/flovo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/flovo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/flovo/orgs',
#      'repos_url': 'https://api.github.com/users/flovo/repos',
#      'events_url': 'https://api.github.com/users/flovo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/flovo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'The AI review is sometimes full of move suggestions (percent points). Many are only poorly explored, some are bad (change of pp much lower than AI choice)\r\n\r\nThis is a suggestion to limit the shown variations to only show the best variations (top 6) and to limit these even further by only showing variations which are well explored.\r\n\r\nAt this point the pps are only shown if it\'s\r\n- the played move,\r\n- the AIs top suggestion, or\r\n- in the AIs top 6 and either\r\n    - at least 5% of the total playouts were spend on the particular variation\r\n        13 playouts for Supporter, 50 playouts for Kyu Supporter, 40 playouts for Dan Supporter or 100 for Pro Supporter\r\n    - or the number of playouts is half or more of the best explored move. (in case there are to much equaly good moves)\r\n\r\nI only tested these values for Kyu Supporter level. There were between 1 and 4 highlighted variations at anytime. \r\n\r\n<details>\r\n<summary>Screenshots</summary>\r\nBefore:\r\n\r\n<img src="https://user-images.githubusercontent.com/4864182/62904867-4a299b80-bd68-11e9-9437-d86be4ea0697.png" />\r\n\r\nAfter:\r\n\r\n<img src="https://user-images.githubusercontent.com/4864182/62904903-6dece180-bd68-11e9-8807-0e5f21655843.png" />\r\n</details>',
#     'created_at': '2019-08-12T23:39:18Z',
#     'updated_at': '2019-08-12T23:39:18Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/online-go/online-go.com/pulls/861/commits',
#     'review_comments_url': 'https://api.github.com/repos/online-go/online-go.com/pulls/861/comments',
#     'review_comment_url': 'https://api.github.com/repos/online-go/online-go.com/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/online-go/online-go.com/issues/861/comments',
#     'statuses_url': 'https://api.github.com/repos/online-go/online-go.com/statuses/df90d0a51d25e4e270374e632832730d49a51a35',
#     'head': {'label': 'flovo:ai-ui-improvement',
#      'ref': 'ai-ui-improvement',
#      'sha': 'df90d0a51d25e4e270374e632832730d49a51a35',
#      'user': {'login': 'flovo',
#       'id': 4864182,
#       'node_id': 'MDQ6VXNlcjQ4NjQxODI=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/4864182?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/flovo',
#       'html_url': 'https://github.com/flovo',
#       'followers_url': 'https://api.github.com/users/flovo/followers',
#       'following_url': 'https://api.github.com/users/flovo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/flovo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/flovo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/flovo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/flovo/orgs',
#       'repos_url': 'https://api.github.com/users/flovo/repos',
#       'events_url': 'https://api.github.com/users/flovo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/flovo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 199511713,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTk1MTE3MTM=',
#       'name': 'online-go.com',
#       'full_name': 'flovo/online-go.com',
#       'private': False,
#       'owner': {'login': 'flovo',
#        'id': 4864182,
#        'node_id': 'MDQ6VXNlcjQ4NjQxODI=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/4864182?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/flovo',
#        'html_url': 'https://github.com/flovo',
#        'followers_url': 'https://api.github.com/users/flovo/followers',
#        'following_url': 'https://api.github.com/users/flovo/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/flovo/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/flovo/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/flovo/subscriptions',
#        'organizations_url': 'https://api.github.com/users/flovo/orgs',
#        'repos_url': 'https://api.github.com/users/flovo/repos',
#        'events_url': 'https://api.github.com/users/flovo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/flovo/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/flovo/online-go.com',
#       'description': 'Source code for the Online-Go.com web interface',
#       'fork': True,
#       'url': 'https://api.github.com/repos/flovo/online-go.com',
#       'forks_url': 'https://api.github.com/repos/flovo/online-go.com/forks',
#       'keys_url': 'https://api.github.com/repos/flovo/online-go.com/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/flovo/online-go.com/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/flovo/online-go.com/teams',
#       'hooks_url': 'https://api.github.com/repos/flovo/online-go.com/hooks',
#       'issue_events_url': 'https://api.github.com/repos/flovo/online-go.com/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/flovo/online-go.com/events',
#       'assignees_url': 'https://api.github.com/repos/flovo/online-go.com/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/flovo/online-go.com/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/flovo/online-go.com/tags',
#       'blobs_url': 'https://api.github.com/repos/flovo/online-go.com/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/flovo/online-go.com/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/flovo/online-go.com/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/flovo/online-go.com/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/flovo/online-go.com/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/flovo/online-go.com/languages',
#       'stargazers_url': 'https://api.github.com/repos/flovo/online-go.com/stargazers',
#       'contributors_url': 'https://api.github.com/repos/flovo/online-go.com/contributors',
#       'subscribers_url': 'https://api.github.com/repos/flovo/online-go.com/subscribers',
#       'subscription_url': 'https://api.github.com/repos/flovo/online-go.com/subscription',
#       'commits_url': 'https://api.github.com/repos/flovo/online-go.com/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/flovo/online-go.com/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/flovo/online-go.com/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/flovo/online-go.com/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/flovo/online-go.com/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/flovo/online-go.com/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/flovo/online-go.com/merges',
#       'archive_url': 'https://api.github.com/repos/flovo/online-go.com/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/flovo/online-go.com/downloads',
#       'issues_url': 'https://api.github.com/repos/flovo/online-go.com/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/flovo/online-go.com/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/flovo/online-go.com/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/flovo/online-go.com/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/flovo/online-go.com/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/flovo/online-go.com/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/flovo/online-go.com/deployments',
#       'created_at': '2019-07-29T19:05:31Z',
#       'updated_at': '2019-07-29T19:05:33Z',
#       'pushed_at': '2019-08-12T23:08:35Z',
#       'git_url': 'git://github.com/flovo/online-go.com.git',
#       'ssh_url': 'git@github.com:flovo/online-go.com.git',
#       'clone_url': 'https://github.com/flovo/online-go.com.git',
#       'svn_url': 'https://github.com/flovo/online-go.com',
#       'homepage': 'https://online-go.com/',
#       'size': 6104,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'devel'}},
#     'base': {'label': 'online-go:devel',
#      'ref': 'devel',
#      'sha': '93c70b6db82c66c446db7600014043207834e6be',
#      'user': {'login': 'online-go',
#       'id': 5840853,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4NDA4NTM=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/5840853?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/online-go',
#       'html_url': 'https://github.com/online-go',
#       'followers_url': 'https://api.github.com/users/online-go/followers',
#       'following_url': 'https://api.github.com/users/online-go/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/online-go/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/online-go/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/online-go/subscriptions',
#       'organizations_url': 'https://api.github.com/users/online-go/orgs',
#       'repos_url': 'https://api.github.com/users/online-go/repos',
#       'events_url': 'https://api.github.com/users/online-go/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/online-go/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 83054351,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4MzA1NDM1MQ==',
#       'name': 'online-go.com',
#       'full_name': 'online-go/online-go.com',
#       'private': False,
#       'owner': {'login': 'online-go',
#        'id': 5840853,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4NDA4NTM=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/5840853?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/online-go',
#        'html_url': 'https://github.com/online-go',
#        'followers_url': 'https://api.github.com/users/online-go/followers',
#        'following_url': 'https://api.github.com/users/online-go/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/online-go/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/online-go/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/online-go/subscriptions',
#        'organizations_url': 'https://api.github.com/users/online-go/orgs',
#        'repos_url': 'https://api.github.com/users/online-go/repos',
#        'events_url': 'https://api.github.com/users/online-go/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/online-go/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/online-go/online-go.com',
#       'description': 'Source code for the Online-Go.com web interface',
#       'fork': False,
#       'url': 'https://api.github.com/repos/online-go/online-go.com',
#       'forks_url': 'https://api.github.com/repos/online-go/online-go.com/forks',
#       'keys_url': 'https://api.github.com/repos/online-go/online-go.com/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/online-go/online-go.com/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/online-go/online-go.com/teams',
#       'hooks_url': 'https://api.github.com/repos/online-go/online-go.com/hooks',
#       'issue_events_url': 'https://api.github.com/repos/online-go/online-go.com/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/online-go/online-go.com/events',
#       'assignees_url': 'https://api.github.com/repos/online-go/online-go.com/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/online-go/online-go.com/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/online-go/online-go.com/tags',
#       'blobs_url': 'https://api.github.com/repos/online-go/online-go.com/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/online-go/online-go.com/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/online-go/online-go.com/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/online-go/online-go.com/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/online-go/online-go.com/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/online-go/online-go.com/languages',
#       'stargazers_url': 'https://api.github.com/repos/online-go/online-go.com/stargazers',
#       'contributors_url': 'https://api.github.com/repos/online-go/online-go.com/contributors',
#       'subscribers_url': 'https://api.github.com/repos/online-go/online-go.com/subscribers',
#       'subscription_url': 'https://api.github.com/repos/online-go/online-go.com/subscription',
#       'commits_url': 'https://api.github.com/repos/online-go/online-go.com/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/online-go/online-go.com/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/online-go/online-go.com/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/online-go/online-go.com/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/online-go/online-go.com/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/online-go/online-go.com/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/online-go/online-go.com/merges',
#       'archive_url': 'https://api.github.com/repos/online-go/online-go.com/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/online-go/online-go.com/downloads',
#       'issues_url': 'https://api.github.com/repos/online-go/online-go.com/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/online-go/online-go.com/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/online-go/online-go.com/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/online-go/online-go.com/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/online-go/online-go.com/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/online-go/online-go.com/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/online-go/online-go.com/deployments',
#       'created_at': '2017-02-24T15:21:23Z',
#       'updated_at': '2019-08-10T16:11:11Z',
#       'pushed_at': '2019-08-12T18:26:37Z',
#       'git_url': 'git://github.com/online-go/online-go.com.git',
#       'ssh_url': 'git@github.com:online-go/online-go.com.git',
#       'clone_url': 'https://github.com/online-go/online-go.com.git',
#       'svn_url': 'https://github.com/online-go/online-go.com',
#       'homepage': 'https://online-go.com/',
#       'size': 6814,
#       'stargazers_count': 508,
#       'watchers_count': 508,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 134,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 185,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'forks': 134,
#       'open_issues': 185,
#       'watchers': 508,
#       'default_branch': 'devel'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/online-go/online-go.com/pulls/861'},
#      'html': {'href': 'https://github.com/online-go/online-go.com/pull/861'},
#      'issue': {'href': 'https://api.github.com/repos/online-go/online-go.com/issues/861'},
#      'comments': {'href': 'https://api.github.com/repos/online-go/online-go.com/issues/861/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/online-go/online-go.com/pulls/861/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/online-go/online-go.com/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/online-go/online-go.com/pulls/861/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/online-go/online-go.com/statuses/df90d0a51d25e4e270374e632832730d49a51a35'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 8,
#     'deletions': 2,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-08-12T23:39:18Z',
#   'org': {'id': 5840853,
#    'login': 'online-go',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/online-go',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5840853?'}},
#  {'id': '10197283082',
#   'type': 'PushEvent',
#   'actor': {'id': 1146750,
#    'login': '8emezzo',
#    'display_login': '8emezzo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/8emezzo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1146750?'},
#   'repo': {'id': 181469924,
#    'name': '8emezzo/8emezzo.github.io',
#    'url': 'https://api.github.com/repos/8emezzo/8emezzo.github.io'},
#   'payload': {'push_id': 3916622111,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8dd4388a14d7d3ca8d2a7ff8809d1795f769d68b',
#    'before': '24f54f3fa2f233983e7f59a672a2dcf9f98d49e8',
#    'commits': [{'sha': '8dd4388a14d7d3ca8d2a7ff8809d1795f769d68b',
#      'author': {'email': '8emezzo@gmail.com', 'name': '8emezzo'},
#      'message': 'HFT',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/8emezzo/8emezzo.github.io/commits/8dd4388a14d7d3ca8d2a7ff8809d1795f769d68b'}]},
#   'public': True,
#   'created_at': '2019-08-12T23:39:18Z'},
#  {'id': '10197283078',
#   'type': 'CreateEvent',
#   'actor': {'id': 10371727,
#    'login': 'navigaid',
#    'display_login': 'navigaid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/navigaid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10371727?'},
#   'repo': {'id': 202025446,
#    'name': 'aur-mirror/sumo-git',
#    'url': 'https://api.github.com/repos/aur-mirror/sumo-git'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-08-12T23:39:18Z',
#   'org': {'id': 53838689,
#    'login': 'aur-mirror',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aur-mirror',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53838689?'}},
#  {'id': '10197283077',
#   'type': 'CreateEvent',
#   'actor': {'id': 53082680,
#    'login': 'jtr7594',
#    'display_login': 'jtr7594',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jtr7594',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53082680?'},
#   'repo': {'id': 202025447,
#    'name': 'jtr7594/test1',
#    'url': 'https://api.github.com/repos/jtr7594/test1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-08-12T23:39:18Z'},
#  {'id': '10197283069',
#   'type': 'PushEvent',
#   'actor': {'id': 12204051,
#    'login': 'marcilr',
#    'display_login': 'marcilr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marcilr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12204051?'},
#   'repo': {'id': 101913084,
#    'name': 'marcilr/filesystem',
#    'url': 'https://api.github.com/repos/marcilr/filesystem'},
#   'payload': {'push_id': 3916622106,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'eec922f4ca6934a8c8df25a1b43bfa26204b1d7f',
#    'before': '881d5645851af69f034d9bc7a24e4ccdfa7f1945',
#    'commits': [{'sha': 'eec922f4ca6934a8c8df25a1b43bfa26204b1d7f',
#      'author': {'email': 'remarcil@alaska.gov', 'name': 'Raymond E. Marcil'},
#      'message': 'Updated.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/marcilr/filesystem/commits/eec922f4ca6934a8c8df25a1b43bfa26204b1d7f'}]},
#   'public': True,
#   'created_at': '2019-08-12T23:39:18Z'},
#  {'id': '10197283070',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 19650611,
#    'name': 'thiagogsr/cara-ou-coroa',
#    'url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa'},
#   'payload': {'action': 'closed',
#    'number': 8,
#    'pull_request': {'url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls/8',
#     'id': 306432134,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzA2NDMyMTM0',
#     'html_url': 'https://github.com/thiagogsr/cara-ou-coroa/pull/8',
#     'diff_url': 'https://github.com/thiagogsr/cara-ou-coroa/pull/8.diff',
#     'patch_url': 'https://github.com/thiagogsr/cara-ou-coroa/pull/8.patch',
#     'issue_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues/8',
#     'number': 8,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump puma from 4.0.1 to 4.1.0',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [puma](https://github.com/puma/puma) from 4.0.1 to 4.1.0.\n<details>\n<summary>Release notes</summary>\n\n*Sourced from [puma\'s releases](https://github.com/puma/puma/releases).*\n\n> ## 4.1.0 - Fourth and One\n> * 4 features \r\n>   * Add REQUEST_PATH on parse error message ([#1831](https://github-redirect.dependabot.com/puma/puma/issues/1831))\r\n>   * You can now easily add custom log formatters with the `log_formatter` config option ([#1816](https://github-redirect.dependabot.com/puma/puma/issues/1816))\r\n>   * Puma.stats now provides process start times ([#1844](https://github-redirect.dependabot.com/puma/puma/issues/1844))\r\n>   * Add support for disabling TLSv1.1 ([#1836](https://github-redirect.dependabot.com/puma/puma/issues/1836))\r\n> \r\n> * 7 bugfixes\r\n>   * Fix issue where Puma was creating zombie process entries ([#1887](https://github-redirect.dependabot.com/puma/puma/issues/1887))\r\n>   * Fix bugs with line-endings and chunked encoding ([#1812](https://github-redirect.dependabot.com/puma/puma/issues/1812))\r\n>   * RACK_URL_SCHEME is now set correctly in all conditions ([#1491](https://github-redirect.dependabot.com/puma/puma/issues/1491))\r\n>   * We no longer mutate global STDOUT/STDERR, particularly the sync setting ([#1837](https://github-redirect.dependabot.com/puma/puma/issues/1837))\r\n>   * SSL read_nonblock no longer blocks ([#1857](https://github-redirect.dependabot.com/puma/puma/issues/1857))\r\n>   * Swallow connection errors when sending early hints ([#1822](https://github-redirect.dependabot.com/puma/puma/issues/1822))\r\n>   * Backtrace no longer dumped when invalid pumactl commands are run ([#1863](https://github-redirect.dependabot.com/puma/puma/issues/1863))\r\n>   \r\n> * 5 other \r\n>   * Avoid casting worker_timeout twice ([#1838](https://github-redirect.dependabot.com/puma/puma/issues/1838))\r\n>   * Removed a call to private that wasn\'t doing anything ([#1882](https://github-redirect.dependabot.com/puma/puma/issues/1882))\r\n>   * README, Rakefile, docs and test cleanups ([#1848](https://github-redirect.dependabot.com/puma/puma/issues/1848), [#1847](https://github-redirect.dependabot.com/puma/puma/issues/1847), [#1846](https://github-redirect.dependabot.com/puma/puma/issues/1846), [#1853](https://github-redirect.dependabot.com/puma/puma/issues/1853), [#1859](https://github-redirect.dependabot.com/puma/puma/issues/1859), [#1850](https://github-redirect.dependabot.com/puma/puma/issues/1850), [#1866](https://github-redirect.dependabot.com/puma/puma/issues/1866), [#1870](https://github-redirect.dependabot.com/puma/puma/issues/1870), [#1872](https://github-redirect.dependabot.com/puma/puma/issues/1872), [#1833](https://github-redirect.dependabot.com/puma/puma/issues/1833), [#1888](https://github-redirect.dependabot.com/puma/puma/issues/1888))\r\n>   * Puma.io has proper documentation now (https://puma.io/puma/)\r\n>   * Added the Contributor Covenant CoC\r\n>   \r\n> * 1 known issue \r\n>   * Some users are still experiencing issues surrounding socket activation and Unix sockets ([#1842](https://github-redirect.dependabot.com/puma/puma/issues/1842))\r\n> \r\n> Codename: Fourth and One\r\n> \r\n> ![why-dont-coaches-go-for-it-on-4th-down](https://user-images.githubusercontent.com/845662/62732073-66c87b00-b9d8-11e9-9d59-add93aad2346.jpg)\r\n</details>\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [puma\'s changelog](https://github.com/puma/puma/blob/master/History.md).*\n\n> ## 4.1.0 / 2019-08-08\n> \n> * 4 features \n>   * Add REQUEST_PATH on parse error message ([#1831](https://github-redirect.dependabot.com/puma/puma/issues/1831))\n>   * You can now easily add custom log formatters with the `log_formatter` config option ([#1816](https://github-redirect.dependabot.com/puma/puma/issues/1816))\n>   * Puma.stats now provides process start times ([#1844](https://github-redirect.dependabot.com/puma/puma/issues/1844))\n>   * Add support for disabling TLSv1.1 ([# ...
#     'created_at': '2019-08-12T10:15:38Z',
#     'updated_at': '2019-08-12T23:39:18Z',
#     'closed_at': '2019-08-12T23:39:17Z',
#     'merged_at': '2019-08-12T23:39:17Z',
#     'merge_commit_sha': '484608e6f8fdfcd6d2181577f5ad9468a26c895f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1348761706,
#       'node_id': 'MDU6TGFiZWwxMzQ4NzYxNzA2',
#       'url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0025ff',
#       'default': False}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls/8/commits',
#     'review_comments_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls/8/comments',
#     'review_comment_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues/8/comments',
#     'statuses_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/statuses/b19e016088d390f72d6d329975028eb678d3469b',
#     'head': {'label': 'thiagogsr:dependabot/bundler/puma-4.1.0',
#      'ref': 'dependabot/bundler/puma-4.1.0',
#      'sha': 'b19e016088d390f72d6d329975028eb678d3469b',
#      'user': {'login': 'thiagogsr',
#       'id': 1802025,
#       'node_id': 'MDQ6VXNlcjE4MDIwMjU=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/1802025?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/thiagogsr',
#       'html_url': 'https://github.com/thiagogsr',
#       'followers_url': 'https://api.github.com/users/thiagogsr/followers',
#       'following_url': 'https://api.github.com/users/thiagogsr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/thiagogsr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/thiagogsr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/thiagogsr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/thiagogsr/orgs',
#       'repos_url': 'https://api.github.com/users/thiagogsr/repos',
#       'events_url': 'https://api.github.com/users/thiagogsr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/thiagogsr/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 19650611,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTY1MDYxMQ==',
#       'name': 'cara-ou-coroa',
#       'full_name': 'thiagogsr/cara-ou-coroa',
#       'private': False,
#       'owner': {'login': 'thiagogsr',
#        'id': 1802025,
#        'node_id': 'MDQ6VXNlcjE4MDIwMjU=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/1802025?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/thiagogsr',
#        'html_url': 'https://github.com/thiagogsr',
#        'followers_url': 'https://api.github.com/users/thiagogsr/followers',
#        'following_url': 'https://api.github.com/users/thiagogsr/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/thiagogsr/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/thiagogsr/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/thiagogsr/subscriptions',
#        'organizations_url': 'https://api.github.com/users/thiagogsr/orgs',
#        'repos_url': 'https://api.github.com/users/thiagogsr/repos',
#        'events_url': 'https://api.github.com/users/thiagogsr/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/thiagogsr/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/thiagogsr/cara-ou-coroa',
#       'description': 'Programa de probabilidade para o jogo de cara ou coroa',
#       'fork': False,
#       'url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa',
#       'forks_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/forks',
#       'keys_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/teams',
#       'hooks_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/hooks',
#       'issue_events_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/events',
#       'assignees_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/tags',
#       'blobs_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/languages',
#       'stargazers_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/stargazers',
#       'contributors_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/contributors',
#       'subscribers_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/subscribers',
#       'subscription_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/subscription',
#       'commits_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/merges',
#       'archive_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/downloads',
#       'issues_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/deployments',
#       'created_at': '2014-05-10T19:54:35Z',
#       'updated_at': '2019-08-12T23:39:10Z',
#       'pushed_at': '2019-08-12T23:39:17Z',
#       'git_url': 'git://github.com/thiagogsr/cara-ou-coroa.git',
#       'ssh_url': 'git@github.com:thiagogsr/cara-ou-coroa.git',
#       'clone_url': 'https://github.com/thiagogsr/cara-ou-coroa.git',
#       'svn_url': 'https://github.com/thiagogsr/cara-ou-coroa',
#       'homepage': None,
#       'size': 30,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'thiagogsr:master',
#      'ref': 'master',
#      'sha': 'bc9dd1059e181b400302115c96f3a3dee521ef85',
#      'user': {'login': 'thiagogsr',
#       'id': 1802025,
#       'node_id': 'MDQ6VXNlcjE4MDIwMjU=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/1802025?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/thiagogsr',
#       'html_url': 'https://github.com/thiagogsr',
#       'followers_url': 'https://api.github.com/users/thiagogsr/followers',
#       'following_url': 'https://api.github.com/users/thiagogsr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/thiagogsr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/thiagogsr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/thiagogsr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/thiagogsr/orgs',
#       'repos_url': 'https://api.github.com/users/thiagogsr/repos',
#       'events_url': 'https://api.github.com/users/thiagogsr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/thiagogsr/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 19650611,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTY1MDYxMQ==',
#       'name': 'cara-ou-coroa',
#       'full_name': 'thiagogsr/cara-ou-coroa',
#       'private': False,
#       'owner': {'login': 'thiagogsr',
#        'id': 1802025,
#        'node_id': 'MDQ6VXNlcjE4MDIwMjU=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/1802025?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/thiagogsr',
#        'html_url': 'https://github.com/thiagogsr',
#        'followers_url': 'https://api.github.com/users/thiagogsr/followers',
#        'following_url': 'https://api.github.com/users/thiagogsr/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/thiagogsr/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/thiagogsr/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/thiagogsr/subscriptions',
#        'organizations_url': 'https://api.github.com/users/thiagogsr/orgs',
#        'repos_url': 'https://api.github.com/users/thiagogsr/repos',
#        'events_url': 'https://api.github.com/users/thiagogsr/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/thiagogsr/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/thiagogsr/cara-ou-coroa',
#       'description': 'Programa de probabilidade para o jogo de cara ou coroa',
#       'fork': False,
#       'url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa',
#       'forks_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/forks',
#       'keys_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/teams',
#       'hooks_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/hooks',
#       'issue_events_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/events',
#       'assignees_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/tags',
#       'blobs_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/languages',
#       'stargazers_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/stargazers',
#       'contributors_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/contributors',
#       'subscribers_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/subscribers',
#       'subscription_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/subscription',
#       'commits_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/merges',
#       'archive_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/downloads',
#       'issues_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/deployments',
#       'created_at': '2014-05-10T19:54:35Z',
#       'updated_at': '2019-08-12T23:39:10Z',
#       'pushed_at': '2019-08-12T23:39:17Z',
#       'git_url': 'git://github.com/thiagogsr/cara-ou-coroa.git',
#       'ssh_url': 'git@github.com:thiagogsr/cara-ou-coroa.git',
#       'clone_url': 'https://github.com/thiagogsr/cara-ou-coroa.git',
#       'svn_url': 'https://github.com/thiagogsr/cara-ou-coroa',
#       'homepage': None,
#       'size': 30,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls/8'},
#      'html': {'href': 'https://github.com/thiagogsr/cara-ou-coroa/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/thiagogsr/cara-ou-coroa/statuses/b19e016088d390f72d6d329975028eb678d3469b'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
# ...
#   'public': True,
#   'created_at': '2019-08-12T23:39:18Z'},
#  {'id': '10197283034',
#   'type': 'PushEvent',
#   'actor': {'id': 14999541,
#    'login': 'casey0808',
#    'display_login': 'casey0808',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/casey0808',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14999541?'},
#   'repo': {'id': 168424965,
#    'name': 'casey0808/casey0808.github.io',
#    'url': 'https://api.github.com/repos/casey0808/casey0808.github.io'},
#   'payload': {'push_id': 3916622079,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1df38b3cce8c300cd8e3026645ac766f1e2623b4',
#    'before': '97b00cc2379dc63861e6a38314d0acb37722f0af',
#    'commits': [{'sha': '1df38b3cce8c300cd8e3026645ac766f1e2623b4',
#      'author': {'email': 'casey_c0808@outlook.com', 'name': 'Casey'},
#      'message': 'Create CNAME',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/casey0808/casey0808.github.io/commits/1df38b3cce8c300cd8e3026645ac766f1e2623b4'}]},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z'},
#  {'id': '10197283033',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46632135,
#    'name': 'Lombiq/Orchard-Token-Title',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Token-Title'},
#   'payload': {'push_id': 3916622080,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.9.2',
#    'head': '17cc9320b3b5783684d755c4a9b17746022c1c0a',
#    'before': '17cc9320b3b5783684d755c4a9b17746022c1c0a',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '10197283031',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46592886,
#    'name': 'Lombiq/Associativy-Core',
#    'url': 'https://api.github.com/repos/Lombiq/Associativy-Core'},
#   'payload': {'push_id': 3916622077,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/Redesign',
#    'head': '8b8bc357cd8a346532884eb4697095451785c9f2',
#    'before': '8b8bc357cd8a346532884eb4697095451785c9f2',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '10197283027',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 18008382,
#    'login': 'hangshao0',
#    'display_login': 'hangshao0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hangshao0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18008382?'},
#   'repo': {'id': 101408117,
#    'name': 'eclipse/openj9',
#    'url': 'https://api.github.com/repos/eclipse/openj9'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/eclipse/openj9/issues/6720',
#     'repository_url': 'https://api.github.com/repos/eclipse/openj9',
#     'labels_url': 'https://api.github.com/repos/eclipse/openj9/issues/6720/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/eclipse/openj9/issues/6720/comments',
#     'events_url': 'https://api.github.com/repos/eclipse/openj9/issues/6720/events',
#     'html_url': 'https://github.com/eclipse/openj9/issues/6720',
#     'id': 479158926,
#     'node_id': 'MDU6SXNzdWU0NzkxNTg5MjY=',
#     'number': 6720,
#     'title': '-Xshareclasses causes crash on Google Cloud Run',
#     'user': {'login': 'gyuuu',
#      'id': 20779253,
#      'node_id': 'MDQ6VXNlcjIwNzc5MjUz',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/20779253?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gyuuu',
#      'html_url': 'https://github.com/gyuuu',
#      'followers_url': 'https://api.github.com/users/gyuuu/followers',
#      'following_url': 'https://api.github.com/users/gyuuu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gyuuu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gyuuu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gyuuu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gyuuu/orgs',
#      'repos_url': 'https://api.github.com/users/gyuuu/repos',
#      'events_url': 'https://api.github.com/users/gyuuu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gyuuu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 822706839,
#       'node_id': 'MDU6TGFiZWw4MjI3MDY4Mzk=',
#       'url': 'https://api.github.com/repos/eclipse/openj9/labels/userRaised',
#       'name': 'userRaised',
#       'color': 'bfdadc',
#       'default': False}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 6,
#     'created_at': '2019-08-09T20:41:34Z',
#     'updated_at': '2019-08-12T23:39:17Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "The **-Xshareclasses** option causes a jvm crash when runing on[ Google Cloud Run](\r\nhttps://cloud.google.com/run/) \r\n\r\nThe error message tells that there is **no free space available**.\r\n\r\nAs Stated on the Filesystem Access section of [this](https://cloud.google.com/run/docs/reference/container-contract) page, **Cloud Run uses some kind of In memory file system**\r\n\r\nI tried this with Micronaut and Spring Boot helloworld applications with both java8 and java11, I assume that any application will fail. **After removing the -Xshareclasses option both appications worked**.\r\nI also tried to set Temporary Directory with TMPDIR env variable to another folder, but that didn't helped either.\r\nSetting the **readonly** option for -Xshareclasses didn't made any difference.\r\n\r\nI set the allocated memory to 1GB so **there should be a lot of free space**, I assume that **OpenJ9 can't determine the free space available with the in memory filesystem**.\r\n\r\n\r\nThe Dockerfiles I tested with:\r\nFROM adoptopenjdk/openjdk11-openj9:alpine\r\nWORKDIR /app\r\nADD target/backend*.jar backend.jar\r\nENV PORT 8080\r\nENV JAVA_OPTS -Xmx256m -Xms256m -Xquickstart -Xtune:virtualized \r\nENV TMPDIR /app/temp\r\nENTRYPOINT java $JAVA_OPTS -XshowSettings:vm -Xshareclasses -Dserver.port=${PORT} -Djava.security.egd=file:/dev/./urandom -jar backend.jar\r\n\r\nFROM adoptopenjdk/openjdk8-openj9:alpine\r\nWORKDIR /app\r\nADD target/backend*.jar backend.jar\r\nENV PORT 8080\r\nENV JAVA_OPTS -Xmx256m -Xms256m -Xquickstart -Xtune:virtualized \r\nENV TMPDIR /app/temp\r\nENTRYPOINT java $JAVA_OPTS -XshowSettings:vm -Xshareclasses -Dserver.port=${PORT} -Djava.security.egd=file:/dev/./urandom -jar backend.jar\r\n\r\nFROM adoptopenjdk/openjdk8-openj9:alpine\r\nWORKDIR /app\r\nADD target/backend*.jar backend.jar\r\nENV PORT 8080\r\nENV JAVA_OPTS -Xmx256m -Xms256m -Xquickstart -Xtune:virtualized \r\nENTRYPOINT java $JAVA_OPTS -XshowSettings:vm -Xshareclasses -Dserver.port=${PORT} -Djava.security.egd=file:/dev/./urandom -jar backend.jar\r\n\r\nThe full error message from Cloud Run logs:\r\n{app_name: Java, facility: 1, hostname: IBM, message: JVMSHRC561E Failed to initialize the shared classes cache, there is not enough space in the file system. Available free disk space bytes = 0, requested bytes = 67108864. , msgid: , procid: 1, severity: 3, structured_data: , timestamp: 2019-08-09T…\r\nJVMSHRC561E Failed to initialize the shared classes cache, there is not enough space in the file system. Available free disk space bytes = 0, requested bytes = 67108864.\r\nJVMJ9VM015W Initialization error for library j9shr29(11): JVMJ9VM009E J9VMDllMain failed"},
#    'comment': {'url': 'https://api.github.com/repos/eclipse/openj9/issues/comments/520633687',
#     'html_url': 'https://github.com/eclipse/openj9/issues/6720#issuecomment-520633687',
#     'issue_url': 'https://api.github.com/repos/eclipse/openj9/issues/6720',
#     'id': 520633687,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDUyMDYzMzY4Nw==',
#     'user': {'login': 'hangshao0',
#      'id': 18008382,
#      'node_id': 'MDQ6VXNlcjE4MDA4Mzgy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/18008382?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/hangshao0',
#      'html_url': 'https://github.com/hangshao0',
#      'followers_url': 'https://api.github.com/users/hangshao0/followers',
#      'following_url': 'https://api.github.com/users/hangshao0/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hangshao0/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/hangshao0/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hangshao0/subscriptions',
#      'organizations_url': 'https://api.github.com/users/hangshao0/orgs',
#      'repos_url': 'https://api.github.com/users/hangshao0/repos',
#      'events_url': 'https://api.github.com/users/hangshao0/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/hangshao0/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-08-12T23:39:17Z',
#     'updated_at': '2019-08-12T23:39:17Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Ahh I see. The filesystem type is overlayfs.\r\n\r\nPlease ignore https://github.com/eclipse/openj9/issues/6720#issuecomment-520619554\r\n\r\nSo the issue here is that the JVM fails to start when you use `-Xshareclasses:cacheDir=/tmp -Xscmx32m`. And it works fine if you create a non-empty file under /tmp. @gyuuu Can you please confirm ?'}},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z',
#   'org': {'id': 56974,
#    'login': 'eclipse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/eclipse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56974?'}},
#  {'id': '10197283025',
#   'type': 'PushEvent',
#   'actor': {'id': 13316680,
#    'login': 'namedun',
#    'display_login': 'namedun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/namedun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13316680?'},
#   'repo': {'id': 135370024,
#    'name': 'tano-systems/meta-tano-openwrt',
#    'url': 'https://api.github.com/repos/tano-systems/meta-tano-openwrt'},
#   'payload': {'push_id': 3916622071,
#    'size': 4,
#    'distinct_size': 0,
#    'ref': 'refs/heads/warrior',
#    'head': '62a4e1aeae35e1a470e17a0153ab6382e5e0ea81',
#    'before': 'ba6a8afb16e1abc4278d9af1076ef6383c632a1c',
#    'commits': [{'sha': '6b76e69bb33bcba617885c5a34639c4c46036c00',
#      'author': {'email': 'a.kikin@tano-systems.com', 'name': 'Anton Kikin'},
#      'message': 'luci: Update to the latest git head\n\nSigned-off-by: Anton Kikin <a.kikin@tano-systems.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tano-systems/meta-tano-openwrt/commits/6b76e69bb33bcba617885c5a34639c4c46036c00'},
#     {'sha': 'aa2a84a36e378525a6ea017290489aa5b064e5a2',
#      'author': {'email': 'a.kikin@tano-systems.com', 'name': 'Anton Kikin'},
#      'message': 'luci-theme-tano: Add recipe for Tano Systems LuCI theme\n\nSigned-off-by: Anton Kikin <a.kikin@tano-systems.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tano-systems/meta-tano-openwrt/commits/aa2a84a36e378525a6ea017290489aa5b064e5a2'},
#     {'sha': '2641a38ecdfc319a4ad3dfaf787802d7e3579db9',
#      'author': {'email': 'a.kikin@tano-systems.com', 'name': 'Anton Kikin'},
#      'message': 'packagegroup: Add luci-theme-tano to packagegroup-openwrt-base\n\nBuild base images with luci-theme-tano. Theme luci-theme-bootstrap\nmoved to packagegroup-openwrt-full.\n\nSigned-off-by: Anton Kikin <a.kikin@tano-systems.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tano-systems/meta-tano-openwrt/commits/2641a38ecdfc319a4ad3dfaf787802d7e3579db9'},
#     {'sha': '62a4e1aeae35e1a470e17a0153ab6382e5e0ea81',
#      'author': {'email': 'a.kikin@tano-systems.com', 'name': 'Anton Kikin'},
#      'message': 'layer: Use luci-theme-tano as default LuCI theme\n\nSigned-off-by: Anton Kikin <a.kikin@tano-systems.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tano-systems/meta-tano-openwrt/commits/62a4e1aeae35e1a470e17a0153ab6382e5e0ea81'}]},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z',
#   'org': {'id': 39713982,
#    'login': 'tano-systems',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tano-systems',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39713982?'}},
#  {'id': '10197283023',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 142673231,
#    'name': 'astronomersiva/lego',
#    'url': 'https://api.github.com/repos/astronomersiva/lego'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/markdown-it-9.1.0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A custom built static site generator that powers https://siva.dev',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z'},
#  {'id': '10197283022',
#   'type': 'WatchEvent',
#   'actor': {'id': 5351275,
#    'login': 'JCBuck',
#    'display_login': 'JCBuck',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JCBuck',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5351275?'},
#   'repo': {'id': 190091795,
#    'name': 'kylelobo/The-Documentation-Compendium',
#    'url': 'https://api.github.com/repos/kylelobo/The-Documentation-Compendium'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z'},
#  {'id': '10197283019',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 140928528,
#    'name': 'matsp/winston-transport-http-stream',
#    'url': 'https://api.github.com/repos/matsp/winston-transport-http-stream'},
#   'payload': {'push_id': 3916622066,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/renovate/eslint-plugin-jest-22.x',
#    'head': '53c893904f0dce3b65f918393d1a60e2b087faa6',
#    'before': '0c3d709bd70637bde7d5fc741c4ef4abf76704b1',
#    'commits': [{'sha': '53c893904f0dce3b65f918393d1a60e2b087faa6',
#      'author': {'email': 'bot@renovateapp.com', 'name': 'Renovate Bot'},
#      'message': 'chore(deps): update dependency eslint-plugin-jest to v22.15.1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/matsp/winston-transport-http-stream/commits/53c893904f0dce3b65f918393d1a60e2b087faa6'}]},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z'},
#  {'id': '10197283015',
#   'type': 'CreateEvent',
#   'actor': {'id': 47985871,
#    'login': 'savageone95',
#    'display_login': 'savageone95',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/savageone95',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47985871?'},
#   'repo': {'id': 202019870,
#    'name': 'savageone95/tamagochi',
#    'url': 'https://api.github.com/repos/savageone95/tamagochi'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'easytamagochi',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-08-12T23:39:17Z'}]

# %%
# %%latex
# This is a equation: $E = mc^2$
# Out:
# This is a equation: $E = mc^2$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as pdr

# %%
gld = pdr.get_data_yahoo('GLD', start='2018-01-01')

# %%
gld=gld.drop('Adj Close', axis=1)

# %%
gld = round(gld, 2)

# %%
gld.head()
# Out:
#               High     Low    Open   Close    Volume
# Date
# 2018-01-02  125.18  124.39  124.66  125.15  11762500
# 2018-01-03  125.09  124.10  125.05  124.82   7904300
# 2018-01-04  125.85  124.74  124.89  125.46   7329700
# 2018-01-05  125.48  124.83  124.93  125.33   5739900
# 2018-01-08  125.32  124.90  125.20  125.31   3566700

# %%
with plt.style.context('ggplot'):
    plt.plot(gld.Close)
